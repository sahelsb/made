# %% [markdown]
# ### Data Exploration for Exercises

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import sqlalchemy as sql
import sqlite3 as sqlite

# %% [markdown]
# #### Load data

# %%
#df = pd.read_csv(r"..//../data/rhein-kreis-neuss-flughafen-weltweit.csv", sep= ";" )
df = pd.read_csv(r"..//../data/stadt-neuss-herbstpflanzung-2023.csv", sep= ";" )
df
# Out:
#      lfd_nr     stadtteil                                     standort  \
# 0     23209      Hammfeld             Stresemannalle Ecke Hammfelddamm
# 1     23092   Furth-Mitte                                Geulenstr. 45
# 2     23422     Weckhoven                       Am Palmstrauch Grünzug
# 3     23429  Reuschenberg                Schwarzer Weg (Hochzeitshain)
# 4     23430  Reuschenberg                Schwarzer Weg (Hochzeitshain)
# ..      ...           ...                                          ...
# 516   22385     Furth-Süd  Karl-Arnold-Str. zw. Josefstr. und Salzstr.
# 517   22389     Furth-Süd                       Karl-Arnold-Str. 12-16
# 518   22391     Furth-Süd                              Wingenderstr. 8
# 519   22397     Furth-Süd                       Karl-Arnold-Str. 12-16
# 520   22401     Furth-Süd                            Weißenberg Weg 83
#
#                  baumart_botanisch           baumart_deutsch  \
# 0                  Castanea sativa               Esskastanie
# 1    Acer platanoides 'Schwedleri'        Ahorn, Roter Spitz
# 2                 Quercus coccinea          Eiche, Scharlach
# 3                  Castanea sativa               Esskastanie
# 4                  Malus domestica  Apfel, Rheinischer Bohn-
# ..                             ...                       ...
# 516              Quercus pubescens              Eiche, Flaum
# 517      Prunus serrulata 'Kanzan'         Kirsche, Jap Zier
# 518              Quercus pubescens              Eiche, Flaum
# 519                 Quercus cerris               Eiche, Zerr
# 520          Amelanchier lamarckii       Felsenbirne, Kupfer
#
#                    id  baumfamilie
# 0    51.1976, 6.71055  Esskastanie
# 1    51.2139, 6.66235        Ahorn
# 2    51.1551, 6.69383        Eiche
# 3     51.174, 6.69221  Esskastanie
# 4    51.1739, 6.69216        Apfel
# ..                ...          ...
# 516   51.2074, 6.6845        Eiche
# 517   51.2086, 6.6846      Kirsche
# 518  51.2094, 6.68474        Eiche
# 519  51.2082, 6.68452        Eiche
# 520  51.2097, 6.67989  Felsenbirne
#
# [521 rows x 7 columns]

# %% [markdown]
# #### Load database

# %%
engine=sql.create_engine('sqlite:///..///../data/trees.sqlite')
with engine.connect() as conn:
    df = pd.read_sql('select * from trees', conn)
df
# Out:
#        stadtteil                                     standort  \
# 0    Furth-Mitte                                Geulenstr. 45
# 1     Furth-Nord                    Im Rottfeld 1 schräg ggb.
# 2     Furth-Nord                            Kaarster Str. 169
# 3     Furth-Nord                    Viersener Str. 53 daneben
# 4     Furth-Nord  Viersener Str. 53 nebenan Grünzug Parkplatz
# ..           ...                                          ...
# 170    Furth-Süd  Karl-Arnold-Str. zw. Josefstr. und Salzstr.
# 171    Furth-Süd                       Karl-Arnold-Str. 12-16
# 172    Furth-Süd                              Wingenderstr. 8
# 173    Furth-Süd                       Karl-Arnold-Str. 12-16
# 174    Furth-Süd                            Weißenberg Weg 83
#
#                  baumart_botanisch                id  baumfamilie
# 0    Acer platanoides 'Schwedleri'  51.2139, 6.66235        Ahorn
# 1         Acer campestre 'Elsrijk'  51.2284, 6.64349        Ahorn
# 2         Acer campestre 'Elsrijk'  51.2274, 6.64892        Ahorn
# 3                  Tilia americana  51.2173, 6.65318        Linde
# 4          Liriodendron tulipifera    51.2174, 6.654   Tulpenbaum
# ..                             ...               ...          ...
# 170              Quercus pubescens   51.2074, 6.6845        Eiche
# 171      Prunus serrulata 'Kanzan'   51.2086, 6.6846      Kirsche
# 172              Quercus pubescens  51.2094, 6.68474        Eiche
# 173                 Quercus cerris  51.2082, 6.68452        Eiche
# 174          Amelanchier lamarckii  51.2097, 6.67989  Felsenbirne
#
# [175 rows x 5 columns]

# %%
pd.__version__
# Out:
# '2.1.4'
