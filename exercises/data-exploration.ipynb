# %% [markdown]
# ### Data Exploration for Exercises

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import sqlalchemy as sql
import sqlite3 as sqlite

# %% [markdown]
# #### Load data

# %%
#df = pd.read_csv(r"..//../data/rhein-kreis-neuss-flughafen-weltweit.csv", sep= ";" )
#df = pd.read_csv(r"..//../data/stadt-neuss-herbstpflanzung-2023.csv", sep= ";" )
df = pd.read_csv(r"..//../data/46131-0014_00.csv", sep= ";" , skiprows=8 , skipfooter=3 , encoding='latin1' )
df
# Out:
# C:\Users\Sahel Bloukat\AppData\Local\Temp\ipykernel_12760\3427993930.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(r"..//../data/46131-0014_00.csv", sep= ";" , skiprows=8 , skipfooter=3 , encoding='latin1' )
#        2024    Januar  NST7-011   Getreide Schleswig-Holstein    -  -.1   -.2  \
# 0      2024    Januar  NST7-011   Getreide            Hamburg    -    -     -
# 1      2024    Januar  NST7-011   Getreide       Braunschweig    -    -  1988
# 2      2024    Januar  NST7-011   Getreide           Hannover    -    -     -
# 3      2024    Januar  NST7-011   Getreide           Lüneburg    -    -     -
# 4      2024    Januar  NST7-011   Getreide          Weser-Ems    -    -     -
# ...     ...       ...       ...        ...                ...  ...  ...   ...
# 41322  2024  Dezember       NaN  Insgesamt            Leipzig  ...  ...   ...
# 41323  2024  Dezember       NaN  Insgesamt     Sachsen-Anhalt  ...  ...   ...
# 41324  2024  Dezember       NaN  Insgesamt          Thüringen  ...  ...   ...
# 41325  2024  Dezember       NaN  Insgesamt            Ausland  ...  ...   ...
# 41326  2024  Dezember       NaN  Insgesamt          Insgesamt  ...  ...   ...
#
#        -.3  -.4  ... -.32 -.33 -.34 -.35   -.36 -.37 -.38 -.39  278  278.1
# 0        -    -  ...    -    -    -    -  13091    -    -    -    -  14397
# 1        -    -  ...    -    -    -    -      -    -    -    -  426   2477
# 2        -    -  ...    -    -    -    -      -    -    -    -    -      -
# 3        -    -  ...    -    -    -    -      -    -    -    -  111    527
# 4        -    -  ...    -    -    -    -      -    -    -    -   50   1210
# ...    ...  ...  ...  ...  ...  ...  ...    ...  ...  ...  ...  ...    ...
# 41322  ...  ...  ...  ...  ...  ...  ...    ...  ...  ...  ...  ...    ...
# 41323  ...  ...  ...  ...  ...  ...  ...    ...  ...  ...  ...  ...    ...
# 41324  ...  ...  ...  ...  ...  ...  ...    ...  ...  ...  ...  ...    ...
# 41325  ...  ...  ...  ...  ...  ...  ...    ...  ...  ...  ...  ...    ...
# 41326  ...  ...  ...  ...  ...  ...  ...    ...  ...  ...  ...  ...    ...
#
# [41327 rows x 47 columns]

# %% [markdown]
# #### Load database

# %%
# engine=sql.create_engine('sqlite:///..///../data/trees.sqlite')
# with engine.connect() as conn:
#     df = pd.read_sql('select * from trees', conn)
# df

engine=sql.create_engine('sqlite:///..///../goodsTransportedByTrain.sqlite')
with engine.connect() as conn:
    df = pd.read_sql('select * from goods', conn)
df
# Out:
#      year    month  goods_id                                       goods_name  \
# 0    2024   Januar  NST7-011                                         Getreide
# 1    2024   Januar  NST7-011                                         Getreide
# 2    2024   Januar  NST7-011                                         Getreide
# 3    2024   Januar  NST7-011                                         Getreide
# 4    2024   Januar  NST7-011                                         Getreide
# ..    ...      ...       ...                                              ...
# 935  2024  Februar  NST7-200  Sonstige Güter, anderweitig nicht klassifiziert
# 936  2024  Februar  NST7-200  Sonstige Güter, anderweitig nicht klassifiziert
# 937  2024  Februar  NST7-200  Sonstige Güter, anderweitig nicht klassifiziert
# 938  2024  Februar  NST7-200  Sonstige Güter, anderweitig nicht klassifiziert
# 939  2024  Februar  NST7-200  Sonstige Güter, anderweitig nicht klassifiziert
#
#      goods_source  abroad   total
# 0    Braunschweig     426    2477
# 1        Lüneburg     111     527
# 2       Weser-Ems      50    1210
# 3            Köln     252     252
# 4         Detmold     166     166
# ..            ...     ...     ...
# 935     Oberpfalz     977     977
# 936      Schwaben    1002    1002
# 937       Dresden    8130    8130
# 938       Ausland     535   11561
# 939     Insgesamt   20706  176994
#
# [940 rows x 7 columns]
